# %%
from aidb import SceneManager, Scene, SceneDef

scm = SceneManager(config='test')
iscm = scm.scene_image_manager()

# %%
scm.scenes_update()

# %%
url = '/home/misw/Data/AI/scenes/0128'
id = '6979e5a1e7438cccb5e231d6' # TEST
#id = scm.id_from_url(url)
scene1 = Scene(scm,id)
#scene2 = Scene(scm,url)
scene3 = scm.scene_from_id_or_url(id)
scene = scene1
print(scene1)
#print(scene2)
print(scene3)

# %%
#scm._dbm.datetime_from_oid(id).astimezone(tz=UTC())
scm._dbm.datetime_from_oid('6989a26c32a845b5c35df55a').timestamp()

# %%
scene.set_rating(1)
scene.update()

# %%
for id in scm.ids_from_rating(-2,2):
    print(id)

# %%
url_img = '/home/misw/Downloads/999_test/ComfyUI_temp_ilmep_00006_.png'
id = iscm.register_from_url(url_img)
id

# %%
url_reg = '/home/misw/Downloads/999_test/orig___697758387ef596695ff19a74.png'
id = iscm.register_from_url(url_img)
id

# %%
scene3._update_thumbnail()

# %%
for id in scm.ids:
    scene = scm.scene_from_id_or_url(id)
    scene.set_labels([])
    scene.update()

# %%
id_img = '6985c340c8b724fc1c4e92d2'
simg = iscm.image_from_id_or_url(id_img)

# %%
simg.data

# %%
simg.url_from_data

# %%
simg.pil

# %%
from aidb.scene import SceneSetManager
ssm = SceneSetManager(config='test', verbose=-1)
id_set = '698af5e39656854a179944c4'

# %%
#ssm.make_new_set('testset', descr='testset_descr', query={'xxx': 'yyy'})

# %%
set = ssm.set_from_id_or_name(id_set)
print(set)

# %%
from pathlib import Path
from ait.tools.files import imgs_from_url
from ait.tools.images import train_from_image, image_from_url
url='/home/misw/Data/AI/scenes_prod/tongue/0001'
for url_img in imgs_from_url(url):
    img = image_from_url(url_img, verbose=True)
    if img is not None:
        pil = train_from_image(img, resolutions=[512], ratios=[1.0])
        url_train = Path(url) / f'train__{url_img.name}'
        print(str(url_train))
        pil.save(url_train)
# Out:
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_22-14-30.png' as PIL image.
# train img resize: [450,425] -> [426,425] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_22-14-30.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_22-07-53.png' as PIL image.
# train img resize: [433,429] -> [429,429] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_22-07-53.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_22-07-27.png' as PIL image.
# train img resize: [804,743] -> [744,743] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_22-07-27.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_22-05-36.png' as PIL image.
# train img resize: [414,411] -> [410,411] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_22-05-36.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_22-03-59.png' as PIL image.
# train img resize: [571,628] -> [571,572] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_22-03-59.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_22-03-25.png' as PIL image.
# train img resize: [677,707] -> [677,677] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_22-03-25.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_22-03-03.png' as PIL image.
# train img resize: [592,572] -> [572,572] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_22-03-03.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_22-02-46.png' as PIL image.
# train img resize: [584,549] -> [548,549] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_22-02-46.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_22-02-35.png' as PIL image.
# train img resize: [576,581] -> [576,576] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_22-02-35.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_22-02-15.png' as PIL image.
# train img resize: [613,618] -> [613,614] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_22-02-15.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_22-02-00.png' as PIL image.
# train img resize: [777,736] -> [736,736] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_22-02-00.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_22-01-17.png' as PIL image.
# train img resize: [410,486] -> [410,410] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_22-01-17.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_22-01-00.png' as PIL image.
# train img resize: [722,778] -> [722,722] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_22-01-00.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_22-00-50.png' as PIL image.
# train img resize: [830,823] -> [822,823] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_22-00-50.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_22-00-34.png' as PIL image.
# train img resize: [671,680] -> [671,672] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_22-00-34.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-59-50.png' as PIL image.
# train img resize: [702,779] -> [702,702] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-59-50.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-57-06.png' as PIL image.
# train img resize: [370,429] -> [370,370] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-57-06.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-55-24.png' as PIL image.
# train img resize: [375,379] -> [375,375] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-55-24.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-54-55.png' as PIL image.
# train img resize: [367,424] -> [367,368] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-54-55.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-53-12.png' as PIL image.
# train img resize: [668,728] -> [668,668] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-53-12.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-52-47.png' as PIL image.
# train img resize: [643,656] -> [643,644] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-52-47.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-52-24.png' as PIL image.
# train img resize: [635,609] -> [609,609] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-52-24.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-52-05.png' as PIL image.
# train img resize: [651,659] -> [651,651] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-52-05.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-51-32.png' as PIL image.
# train img resize: [481,527] -> [481,481] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-51-32.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-51-19.png' as PIL image.
# train img resize: [502,584] -> [502,502] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-51-19.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-51-03.png' as PIL image.
# train img resize: [589,716] -> [589,588] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-51-03.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-50-32.png' as PIL image.
# train img resize: [617,782] -> [617,618] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-50-32.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-50-11.png' as PIL image.
# train img resize: [503,552] -> [503,504] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-50-11.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-49-53.png' as PIL image.
# train img resize: [490,491] -> [490,490] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-49-53.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-48-06.png' as PIL image.
# train img resize: [442,464] -> [442,442] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-48-06.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-47-43.png' as PIL image.
# train img resize: [590,602] -> [590,590] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-47-43.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-47-30.png' as PIL image.
# train img resize: [474,537] -> [474,474] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-47-30.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-47-20.png' as PIL image.
# train img resize: [448,511] -> [448,448] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-47-20.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-46-59.png' as PIL image.
# train img resize: [321,386] -> [321,322] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-46-59.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-46-43.png' as PIL image.
# train img resize: [462,509] -> [462,462] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-46-43.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-46-26.png' as PIL image.
# train img resize: [596,623] -> [596,596] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-46-26.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-45-30.png' as PIL image.
# train img resize: [435,481] -> [435,435] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-45-30.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-44-43.png' as PIL image.
# train img resize: [486,472] -> [472,472] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-44-43.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-44-22.png' as PIL image.
# train img resize: [483,505] -> [483,483] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-44-22.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-43-53.png' as PIL image.
# train img resize: [494,523] -> [494,494] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-43-53.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-43-31.png' as PIL image.
# train img resize: [501,524] -> [501,500] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-43-31.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-40-29.png' as PIL image.
# train img resize: [505,530] -> [505,506] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-40-29.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-39-43.png' as PIL image.
# train img resize: [454,491] -> [454,454] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-39-43.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-36-33.png' as PIL image.
# train img resize: [556,494] -> [494,494] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-36-33.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-33-17.png' as PIL image.
# train img resize: [532,593] -> [532,532] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-33-17.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-33-00.png' as PIL image.
# train img resize: [491,584] -> [491,492] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-33-00.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-32-42.png' as PIL image.
# train img resize: [490,793] -> [490,490] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-32-42.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-32-23.png' as PIL image.
# train img resize: [491,721] -> [491,491] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-32-23.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-31-52.png' as PIL image.
# train img resize: [487,686] -> [487,486] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-31-52.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-31-40.png' as PIL image.
# train img resize: [481,708] -> [481,480] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-31-40.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-31-28.png' as PIL image.
# train img resize: [478,790] -> [478,478] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-31-28.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-31-04.png' as PIL image.
# train img resize: [554,825] -> [554,554] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-31-04.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-29-39.png' as PIL image.
# train img resize: [302,356] -> [302,302] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-29-39.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-29-20.png' as PIL image.
# train img resize: [317,361] -> [317,317] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-29-20.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-27-44.png' as PIL image.
# train img resize: [310,232] -> [232,232] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-27-44.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-27-26.png' as PIL image.
# train img resize: [278,234] -> [234,234] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-27-26.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-10-33.png' as PIL image.
# train img resize: [549,590] -> [549,550] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-10-33.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-09-03.png' as PIL image.
# train img resize: [369,385] -> [369,369] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-09-03.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-07-56.png' as PIL image.
# train img resize: [659,572] -> [572,572] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-07-56.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-07-21.png' as PIL image.
# train img resize: [474,436] -> [436,436] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-07-21.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-06-39.png' as PIL image.
# train img resize: [350,343] -> [342,343] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-06-39.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-05-47.png' as PIL image.
# train img resize: [354,383] -> [354,354] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-05-47.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-05-29.png' as PIL image.
# train img resize: [379,426] -> [379,378] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-05-29.png
# Successfully opened image '/home/misw/Data/AI/scenes_prod/tongue/0001/screenshot-2026-02-09_21-05-04.png' as PIL image.
# train img resize: [395,441] -> [395,395] -> [512,512]
# /home/misw/Data/AI/scenes_prod/tongue/0001/train__screenshot-2026-02-09_21-05-04.png
