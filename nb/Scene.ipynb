# %%
from aidb.scene_manager import SceneManager
from aidb.scene import Scene

scm = SceneManager()
# Out:
# MongoDB connection configuration loaded from '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_test_scenes.yaml'.
# Thumbnail configuration loaded from '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_test_scenes.yaml'.
# Train image configuration loaded from '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_test_scenes.yaml'.
# ...
# Successfully connected to MongoDB at mongodb://mongo:mongo@192.168.0.120:27017, database: test_scenes
# Using collection

# %%
id = "696c204169ff1265f6ff4968"
scene = Scene(scm,id)
print(scene)
# Out:
# {'_id': ObjectId('696c204169ff1265f6ff4968'),
#  'id': '696c204169ff1265f6ff4968',
#  'url': '/home/misw/Data/AI/scenes/0127'}

# %%
data = scene.data
scene._data |= {"sepp": "depp"}

# %%
from ait.tools.files import postfix_img
postfix_img()
# Out:
# ['.png',
#  '.webp',
#  '.jpg',
#  '.jpeg',
#  '.Png',
#  '.Webp',
#  '.Jpg',
#  '.Jpeg',
#  '.PNG',
#  '.WEBP',
#  '.JPG',
#  '.JPEG']
