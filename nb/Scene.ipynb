# %%
from aidb import SceneManager, Scene, SceneDef

scm = SceneManager(config=SceneDef.CONFIG_PROD)
iscm = scm.scene_image_manager()
# Out:
# [dbm:message] MongoDB connection configuration loaded from '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_scenes_prod.yaml'.
# [dbm:message] Thumbnail configuration loaded from '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_scenes_prod.yaml'.
# [dbm:message] Train image configuration loaded from '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_scenes_prod.yaml'.
# [dbm:message] Warning: 'hf_dataset_settings' section not found or malformed in '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_scenes_prod.yaml'. Using default HF dataset settings.
# [dbm:message] Successfully connected to MongoDB at mongodb://mongo:mongo@192.168.0.120:27017, database: scenes_prod
# [dbm:message] Using collection

# %%
scm.scenes_update()
# Out:
# [scene id(6979ed790a75d3d578dfe48b):message] thumbnail update.
# [scene id(6979ed790a75d3d578dfe48c):message] thumbnail update.
# [scene id(6979ed790a75d3d578dfe48f):message] thumbnail update.
# [scene id(69805404412ea85b2e7aa283):message] thumbnail update.
# [scene id(698054bc33216bc5f441f64a):message] thumbnail update.
# [scene id(69805502f914092bdf02cc15):message] thumbnail update.
# [scene id(69805515484a7a578bf150f2):message] thumbnail update.
# [scene id(69805529425a757989d82c14):message] thumbnail update.
# [scene id(6980555b5f14f75c1e2c77e4):message] thumbnail update.
# [scene id(69805574daded8fd1a6ab12b):message] thumbnail update.
# [scene id(69805591b8eb7e0c05a48018):message] thumbnail update.
# [scene id(698055af34146482d9353584):message] thumbnail update.
# [scene id(698055c8ae799b2c73c45aad):message] thumbnail update.
# [scene id(6980560fb0642ebf3f1134fc):message] thumbnail update.
# [scene id(6980562852289da7b82f514f):message] thumbnail update.
# [scene id(6980565a5a8f6db8a81c33e9):message] thumbnail update.
# [scene id(6980583ed6412dd225de41a1):message] thumbnail update.
# [scene id(69805874e5a36b0f872e0390):message] thumbnail update.
# [scene id(698058a5d54773f38b0891b7):message] thumbnail update.
# [scene id(6980590bd4892464626cec7f):message] thumbnail update.
# [scene id(69805949fd5bd20c35a745cb):message] thumbnail update.
# [scene id(6980599a5cbf5e2a79c80a18):message] thumbnail update.
# [scene id(698059d5e36095ac562919f1):message] thumbnail update.
# [scene id(69805a08e997ed51abbc4773):message] thumbnail update.
# [scene id(69805a3a4f85fc86aec6fc3d):message] thumbnail update.
# [scene id(69805a586c74b8f6d4faff04):message] thumbnail update.
# [scene id(69805aab7f10214d49127bd5):message] thumbnail update.
# [scene id(69805b543475ff96de85ed9c):message] thumbnail update.
# [scene id(69805b6e5817d6adf1bd3455):message] thumbnail update.
# [scene id(69805b8cd130222a448bb2e3):message] thumbnail update.
# [scene id(69805ba64234ff3fa6462270):message] thumbnail update.
# [scene id(69805c022f0644371552d686):message] thumbnail update.
# [scene id(69805c1ed5c67b3c84a55a5a):message] thumbnail update.
# [scene id(69805c4e688df0899cae4a30):message] thumbnail update.
# [scene id(69805c71f440186c133fbe2b):message] thumbnail update.
# [scene id(69805c968d55211d5396f7b0):message] thumbnail update.
# [scene id(69805cc6e19bc661b424fca2):message] thumbnail update.
# [scene id(69805cffabd2d3e367080c3d):message] thumbnail update.

# %%
url = '/home/misw/Data/AI/scenes/0128'
id = '696e2ed878deb8af7a6d79fc'
#id = scm.id_from_url(url)
scene1 = Scene(scm,id)
scene2 = Scene(scm,url)
scene = scene1
print(scene1)
print(scene2)

# %%
scene3 = scm.scene_from_id_or_url(id)

# %%
print(scene3)

# %%
scene4 = scm.scene_from_id_or_url(url)

# %%
print(scene4)

# %%
url_img = '/home/misw/Downloads/999_test/ComfyUI_temp_ilmep_00006_.png'
id = iscm.register_from_url(url_img)
id

# %%
url_reg = '/home/misw/Downloads/999_test/orig___697758387ef596695ff19a74.png'
id = iscm.register_from_url(url_img)
id

# %%
scene3._update_thumbnail()
