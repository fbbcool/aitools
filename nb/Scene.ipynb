# %%
from aidb import SceneManager, Scene, SceneDef

scm = SceneManager(config=SceneDef.CONFIG_PROD)
iscm = scm.scene_image_manager()
# Out:
# [dbm:message] MongoDB connection configuration loaded from '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_scenes_prod.yaml'.
# [dbm:message] Thumbnail configuration loaded from '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_scenes_prod.yaml'.
# [dbm:message] Train image configuration loaded from '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_scenes_prod.yaml'.
# [dbm:message] Warning: 'hf_dataset_settings' section not found or malformed in '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_scenes_prod.yaml'. Using default HF dataset settings.
# [dbm:message] Successfully connected to MongoDB at mongodb://mongo:mongo@192.168.0.120:27017, database: scenes_prod
# [dbm:message] Using collection

# %%
scm.scenes_update()

# %%
url = '/home/misw/Data/AI/scenes/0128'
id = '6979e5a1e7438cccb5e231d6' # TEST
#id = scm.id_from_url(url)
scene1 = Scene(scm,id)
#scene2 = Scene(scm,url)
scene3 = scm.scene_from_id_or_url(id)
scene = scene1
print(scene1)
#print(scene2)
print(scene3)

# %%
scene.set_rating(1)
scene.update()

# %%
for id in scm.ids_from_rating(-2,2):
    print(id)

# %%
url_img = '/home/misw/Downloads/999_test/ComfyUI_temp_ilmep_00006_.png'
id = iscm.register_from_url(url_img)
id

# %%
url_reg = '/home/misw/Downloads/999_test/orig___697758387ef596695ff19a74.png'
id = iscm.register_from_url(url_img)
id

# %%
scene3._update_thumbnail()

# %%
for id in scm.ids:
    scene = scm.scene_from_id_or_url(id)
    scene.set_rating(-1)
    scene.update()
# Out:
# [scene id(6979ed1109bc968f483a60f1):message] data update.
# [scene id(6979ed790a75d3d578dfe485):message] data update.
# [scene id(6979ed790a75d3d578dfe486):message] data update.
# [scene id(6979ed790a75d3d578dfe487):message] data update.
# [scene id(6979ed790a75d3d578dfe488):message] data update.
# [scene id(6979ed790a75d3d578dfe489):message] data update.
# [scene id(6979ed790a75d3d578dfe48a):message] data update.
# [scene id(6979ed790a75d3d578dfe48b):message] data update.
# [scene id(6979ed790a75d3d578dfe48c):message] data update.
# [scene id(6979ed790a75d3d578dfe48d):message] data update.
# [scene id(6979ed790a75d3d578dfe48e):message] data update.
# [scene id(6979ed790a75d3d578dfe48f):message] data update.
# [scene id(6979ed7a0a75d3d578dfe490):message] data update.
# [scene id(6979ed7a0a75d3d578dfe491):message] data update.
# [scene id(6979ed7a0a75d3d578dfe492):message] data update.
# [scene id(6979ed7a0a75d3d578dfe493):message] data update.
# [scene id(6979ed7a0a75d3d578dfe494):message] data update.
# [scene id(6979ed7a0a75d3d578dfe495):message] data update.
# [scene id(6979ed7a0a75d3d578dfe496):message] data update.
# [scene id(6979ed7a0a75d3d578dfe497):message] data update.
# [scene id(6979ed7a0a75d3d578dfe498):message] data update.
# [scene id(6979ed7a0a75d3d578dfe499):message] data update.
# [scene id(6979ed7a0a75d3d578dfe49a):message] data update.
# [scene id(6979ed7a0a75d3d578dfe49b):message] data update.
# [scene id(6979ed7a0a75d3d578dfe49c):message] data update.
# [scene id(6979ed7a0a75d3d578dfe49d):message] data update.
# [scene id(6979ed7a0a75d3d578dfe49e):message] data update.
# [scene id(6979ed7a0a75d3d578dfe49f):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4a0):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4a1):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4a2):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4a3):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4a4):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4a5):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4a6):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4a7):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4a8):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4a9):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4aa):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4ab):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4ac):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4ad):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4ae):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4af):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4b0):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4b1):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4b2):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4b3):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4b4):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4b5):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4b6):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4b7):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4b8):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4b9):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4ba):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4bb):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4bc):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4bd):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4be):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4bf):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4c0):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4c1):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4c2):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4c3):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4c4):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4c5):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4c6):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4c7):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4c8):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4c9):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4ca):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4cb):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4cc):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4cd):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4ce):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4cf):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4d0):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4d1):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4d2):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4d3):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4d4):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4d5):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4d6):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4d7):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4d8):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4d9):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4da):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4db):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4dc):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4dd):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4de):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4df):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4e0):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4e1):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4e2):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4e3):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4e4):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4e5):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4e6):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4e7):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4e8):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4e9):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4ea):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4eb):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4ec):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4ed):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4ee):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4ef):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4f0):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4f1):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4f2):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4f3):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4f4):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4f5):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4f6):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4f7):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4f8):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4f9):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4fa):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4fb):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4fc):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4fd):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4fe):message] data update.
# [scene id(6979ed7a0a75d3d578dfe4ff):message] data update.
# [scene id(6979ed7a0a75d3d578dfe500):message] data update.
# [scene id(6979ed7a0a75d3d578dfe501):message] data update.
# [scene id(6979ed7a0a75d3d578dfe502):message] data update.
# [scene id(6979ed7a0a75d3d578dfe503):message] data update.
# [scene id(6979ed7a0a75d3d578dfe504):message] data update.
# [scene id(6979ed7a0a75d3d578dfe505):message] data update.
# [scene id(6979ed7a0a75d3d578dfe506):message] data update.
# [scene id(6979ed7a0a75d3d578dfe507):message] data update.
# [scene id(6979ed7a0a75d3d578dfe508):message] data update.
# [scene id(6979ed7a0a75d3d578dfe509):message] data update.
# [scene id(6979ed7a0a75d3d578dfe50a):message] data update.
# [scene id(6979edd3a65b872466c06294):message] data update.
# [scene id(6979edd3a65b872466c06295):message] data update.
# [scene id(6979edd3a65b872466c06296):message] data update.
# [scene id(6979edd3a65b872466c06297):message] data update.
# [scene id(6979edd3a65b872466c06298):message] data update.
# [scene id(6979edd4a65b872466c06299):message] data update.
# [scene id(6979edd4a65b872466c0629a):message] data update.
# [scene id(6979edd4a65b872466c0629b):message] data update.
# [scene id(6979edd4a65b872466c0629c):message] data update.
# [scene id(6979edd4a65b872466c0629d):message] data update.
# [scene id(6979edd4a65b872466c0629e):message] data update.
# [scene id(6979edd4a65b872466c0629f):message] data update.
# [scene id(6979edd4a65b872466c062a0):message] data update.
# [scene id(6979edd4a65b872466c062a1):message] data update.
# [scene id(6979edd4a65b872466c062a2):message] data update.
# [scene id(6979edd4a65b872466c062a3):message] data update.
# [scene id(6979edd4a65b872466c062a4):message] data update.
# [scene id(6979edd4a65b872466c062a5):message] data update.
# [scene id(6979edd4a65b872466c062a6):message] data update.
# [scene id(6979edd4a65b872466c062a7):message] data update.
# [scene id(6979edd4a65b872466c062a8):message] data update.
# [scene id(6979edd4a65b872466c062a9):message] data update.
# [scene id(6979edd4a65b872466c062aa):message] data update.
# [scene id(6979edd4a65b872466c062ab):message] data update.
# [scene id(6979edd4a65b872466c062ac):message] data update.
# [scene id(6979edd4a65b872466c062ad):message] data update.
# [scene id(6979edd4a65b872466c062ae):message] data update.
# [scene id(6979edd4a65b872466c062af):message] data update.
# [scene id(6979edd4a65b872466c062b0):message] data update.
# [scene id(6979edd4a65b872466c062b1):message] data update.
# [scene id(6979edd4a65b872466c062b2):message] data update.
# [scene id(6979edd4a65b872466c062b3):message] data update.
# [scene id(6979edd4a65b872466c062b4):message] data update.
# [scene id(6979edd4a65b872466c062b5):message] data update.
# [scene id(6979edd4a65b872466c062b6):message] data update.
# [scene id(6979edd4a65b872466c062b7):message] data update.
# [scene id(6979edd4a65b872466c062b8):message] data update.
# [scene id(6979edd4a65b872466c062b9):message] data update.
# [scene id(6979edd4a65b872466c062ba):message] data update.
# [scene id(6979edd4a65b872466c062bb):message] data update.
# [scene id(6979edd4a65b872466c062bc):message] data update.
# [scene id(6979edd4a65b872466c062bd):message] data update.
# [scene id(6979edd4a65b872466c062be):message] data update.
# [scene id(6979edd4a65b872466c062bf):message] data update.
# [scene id(6979edd4a65b872466c062c0):message] data update.
# [scene id(6979edd4a65b872466c062c1):message] data update.
# [scene id(6979edd4a65b872466c062c2):message] data update.
# [scene id(6979edd4a65b872466c062c3):message] data update.
# [scene id(6979edd4a65b872466c062c4):message] data update.
# [scene id(6979edd4a65b872466c062c5):message] data update.
# [scene id(6979edd4a65b872466c062c6):message] data update.
# [scene id(6979edd4a65b872466c062c7):message] data update.
# [scene id(6979edd4a65b872466c062c8):message] data update.
# [scene id(6979edd4a65b872466c062c9):message] data update.
# [scene id(6979edd4a65b872466c062ca):message] data update.
# [scene id(6979edd4a65b872466c062cb):message] data update.
# [scene id(6979edd4a65b872466c062cc):message] data update.
# [scene id(6979edd4a65b872466c062cd):message] data update.
# [scene id(6979edd4a65b872466c062ce):message] data update.
# [scene id(6979edd4a65b872466c062cf):message] data update.
# [scene id(6979edd4a65b872466c062d0):message] data update.
# [scene id(6979edd4a65b872466c062d1):message] data update.
# [scene id(6979edd4a65b872466c062d2):message] data update.
# [scene id(6979edd4a65b872466c062d3):message] data update.
# [scene id(6979edd4a65b872466c062d4):message] data update.
# [scene id(6979edd4a65b872466c062d5):message] data update.
# [scene id(6979edd4a65b872466c062d6):message] data update.
# [scene id(6979edd4a65b872466c062d7):message] data update.
# [scene id(6979edd4a65b872466c062d8):message] data update.
# [scene id(6979edd4a65b872466c062d9):message] data update.
# [scene id(6979edd4a65b872466c062da):message] data update.
# [scene id(6979edd4a65b872466c062db):message] data update.
# [scene id(6979edd4a65b872466c062dc):message] data update.
# [scene id(6979edd4a65b872466c062dd):message] data update.
# [scene id(6979edd4a65b872466c062de):message] data update.
# [scene id(6979edd4a65b872466c062df):message] data update.
# [scene id(6979edd4a65b872466c062e0):message] data update.
# [scene id(6979edd4a65b872466c062e1):message] data update.
# [scene id(6979edd4a65b872466c062e2):message] data update.
# [scene id(6979edd4a65b872466c062e3):message] data update.
# [scene id(6979edd4a65b872466c062e4):message] data update.
# [scene id(6979edd4a65b872466c062e5):message] data update.
# [scene id(6979edd4a65b872466c062e6):message] data update.
# [scene id(6979edd4a65b872466c062e7):message] data update.
# [scene id(6979edd4a65b872466c062e8):message] data update.
# [scene id(6979edd4a65b872466c062e9):message] data update.
# [scene id(6979edd4a65b872466c062ea):message] data update.
# [scene id(6979edd4a65b872466c062eb):message] data update.
# [scene id(6979edd4a65b872466c062ec):message] data update.
# [scene id(6979edd4a65b872466c062ed):message] data update.
# [scene id(6979edd4a65b872466c062ee):message] data update.
# [scene id(6979edd4a65b872466c062ef):message] data update.
# [scene id(6979edd4a65b872466c062f0):message] data update.
# [scene id(6979edd4a65b872466c062f1):message] data update.
# [scene id(6979edd4a65b872466c062f2):message] data update.
# [scene id(6979edd4a65b872466c062f3):message] data update.
# [scene id(6979edd4a65b872466c062f4):message] data update.
# [scene id(6979edd4a65b872466c062f5):message] data update.
# [scene id(6979edd4a65b872466c062f6):message] data update.
# [scene id(6979edd4a65b872466c062f7):message] data update.
# [scene id(6979edd4a65b872466c062f8):message] data update.
# [scene id(6979edd4a65b872466c062f9):message] data update.
# [scene id(6979edd4a65b872466c062fa):message] data update.
# [scene id(6979edd4a65b872466c062fb):message] data update.
# [scene id(6979edd4a65b872466c062fc):message] data update.
# [scene id(6979edd4a65b872466c062fd):message] data update.
# [scene id(6979edd4a65b872466c062fe):message] data update.
# [scene id(6979edd4a65b872466c062ff):message] data update.
# [scene id(6979edd4a65b872466c06300):message] data update.
# [scene id(6979edd4a65b872466c06301):message] data update.
# [scene id(6979edd4a65b872466c06302):message] data update.
# [scene id(6979edd4a65b872466c06303):message] data update.
# [scene id(6979edd4a65b872466c06304):message] data update.
# [scene id(6979edd4a65b872466c06305):message] data update.
# [scene id(6979edd4a65b872466c06306):message] data update.
# [scene id(6979edd4a65b872466c06307):message] data update.
# [scene id(6979edd4a65b872466c06308):message] data update.
# [scene id(6979edd4a65b872466c06309):message] data update.
# [scene id(6979edd4a65b872466c0630a):message] data update.
# [scene id(6979edd4a65b872466c0630b):message] data update.
# [scene id(6979edd4a65b872466c0630c):message] data update.
# [scene id(6979edd4a65b872466c0630d):message] data update.
# [scene id(6979edd4a65b872466c0630e):message] data update.
# [scene id(6979edd4a65b872466c0630f):message] data update.
# [scene id(6979edd4a65b872466c06310):message] data update.
# [scene id(6979edd4a65b872466c06311):message] data update.
# [scene id(6979edd4a65b872466c06312):message] data update.
# [scene id(6979edd4a65b872466c06313):message] data update.
# [scene id(6979edd4a65b872466c06314):message] data update.
# [scene id(6979ee192e61e8082bdedc19):message] data update.
# [scene id(6979ee192e61e8082bdedc1a):message] data update.
# [scene id(6979ee192e61e8082bdedc1b):message] data update.
# [scene id(6979ee33b0fee1bc35e1903d):message] data update.
# [scene id(6979ee33b0fee1bc35e1903e):message] data update.
# [scene id(6979ee33b0fee1bc35e1903f):message] data update.
# [scene id(6979ee33b0fee1bc35e19040):message] data update.
# [scene id(6979ee33b0fee1bc35e19041):message] data update.
# [scene id(6979ee33b0fee1bc35e19042):message] data update.
# [scene id(6979ee33b0fee1bc35e19043):message] data update.
# [scene id(6979ee34b0fee1bc35e19044):message] data update.
# [scene id(6979ee34b0fee1bc35e19045):message] data update.
# [scene id(6979ee34b0fee1bc35e19046):message] data update.
# [scene id(6979ee34b0fee1bc35e19047):message] data update.
# [scene id(6979ee34b0fee1bc35e19048):message] data update.
# [scene id(6979ee34b0fee1bc35e19049):message] data update.
# [scene id(6979ee34b0fee1bc35e1904a):message] data update.
# [scene id(6979ee34b0fee1bc35e1904b):message] data update.
# [scene id(6979ee34b0fee1bc35e1904c):message] data update.
# [scene id(69805404412ea85b2e7aa283):message] data update.
# [scene id(698054bc33216bc5f441f64a):message] data update.
# [scene id(69805502f914092bdf02cc15):message] data update.
# [scene id(69805515484a7a578bf150f2):message] data update.
# [scene id(69805529425a757989d82c14):message] data update.
# [scene id(6980555b5f14f75c1e2c77e4):message] data update.
# [scene id(69805574daded8fd1a6ab12b):message] data update.
# [scene id(69805591b8eb7e0c05a48018):message] data update.
# [scene id(698055af34146482d9353584):message] data update.
# [scene id(698055c8ae799b2c73c45aad):message] data update.
# [scene id(6980560fb0642ebf3f1134fc):message] data update.
# [scene id(6980562852289da7b82f514f):message] data update.
# [scene id(6980565a5a8f6db8a81c33e9):message] data update.
# [scene id(6980583ed6412dd225de41a1):message] data update.
# [scene id(69805874e5a36b0f872e0390):message] data update.
# [scene id(698058a5d54773f38b0891b7):message] data update.
# [scene id(6980590bd4892464626cec7f):message] data update.
# [scene id(69805949fd5bd20c35a745cb):message] data update.
# [scene id(6980599a5cbf5e2a79c80a18):message] data update.
# [scene id(698059d5e36095ac562919f1):message] data update.
# [scene id(69805a08e997ed51abbc4773):message] data update.
# [scene id(69805a3a4f85fc86aec6fc3d):message] data update.
# [scene id(69805a586c74b8f6d4faff04):message] data update.
# [scene id(69805aab7f10214d49127bd5):message] data update.
# [scene id(69805b543475ff96de85ed9c):message] data update.
# [scene id(69805b6e5817d6adf1bd3455):message] data update.
# [scene id(69805b8cd130222a448bb2e3):message] data update.
# [scene id(69805ba64234ff3fa6462270):message] data update.
# [scene id(69805c022f0644371552d686):message] data update.
# [scene id(69805c1ed5c67b3c84a55a5a):message] data update.
# [scene id(69805c4e688df0899cae4a30):message] data update.
# [scene id(69805c71f440186c133fbe2b):message] data update.
# [scene id(69805c968d55211d5396f7b0):message] data update.
# [scene id(69805cc6e19bc661b424fca2):message] data update.
# [scene id(69805cffabd2d3e367080c3d):message] data update.
# [scene id(69805d6bbdf018a8b73bf98f):message] data update.
# [scene id(69805da0196f9d8962524104):message] data update.
# [scene id(69805dd327adb1fd8ad9a43d):message] data update.
# [scene id(69805e00553eaaa1b4b03c47):message] data update.
# [scene id(69805e1ce9d19aa222f1c632):message] data update.
# [scene id(69805e3244495634c48beea4):message] data update.
# [scene id(69805e4392ab3ae23d2939ac):message] data update.
# [scene id(69805e5906b9b8b3a8f11270):message] data update.
# [scene id(69805e6ee4d486d5162c6439):message] data update.
# [scene id(69805e7ca90e70381c54d22e):message] data update.
# [scene id(69805e8e39233a5401dc429a):message] data update.
# [scene id(69805ea492de1f62671e8807):message] data update.
# [scene id(69805eda9ed8a8435a0ab09f):message] data update.
# [scene id(69805efd76a2aabe0c3f1a9e):message] data update.
# [scene id(69805f3126602f9395f72251):message] data update.
# [scene id(69805f69991075ff2ad21d20):message] data update.
# [scene id(69805fcd6fe387360854b13b):message] data update.
# [scene id(6980603f788c4b76fa798b15):message] data update.
# [scene id(6980605b2067a68f4484bd2f):message] data update.
# [scene id(6980607720bcb5dac3a4a531):message] data update.
# [scene id(698060c55cc8bde696352165):message] data update.
# [scene id(698060e04d20e0de5498107b):message] data update.
# [scene id(6980611077f4ce8cc3f56af2):message] data update.
# [scene id(69806169ee697d6760fc2f28):message] data update.
# [scene id(698061dabf9698763c71ab82):message] data update.
# [scene id(698061f096a803422b2c1259):message] data update.
# [scene id(6980623da1dba9391d7199c5):message] data update.
# [scene id(698062663ab8a44d7d4824e5):message] data update.
# [scene id(69806283257d59d9388c6fd6):message] data update.
# [scene id(69806293b4bf2cb6c2432a93):message] data update.
# [scene id(698062b20c010afc7b1b4845):message] data update.
# [scene id(698062ce522de62c4f985759):message] data update.
# [scene id(698062e29f992395616220ef):message] data update.
# [scene id(6980632c02f8d7bdb071e854):message] data update.
# [scene id(6980637c4de8c6d1ba65145e):message] data update.
# [scene id(6980639cae36fcb30828772c):message] data update.
# [scene id(698063b3616f4e73beb2f5c1):message] data update.
# [scene id(698063d25e3b23d7d69b8b8b):message] data update.
# [scene id(698063e9fc160bf39713c088):message] data update.
# [scene id(69806407c364508060a761e6):message] data update.
# [scene id(6980643086b21989c7c80482):message] data update.
# [scene id(6980644458c5922311b3b642):message] data update.
# [scene id(6980646f72531e55854142c0):message] data update.
# [scene id(69806482ce981cb601d11b81):message] data update.
# [scene id(698064a1a3c18684d446a17d):message] data update.
# [scene id(698064c007ae374e40370f0c):message] data update.
# [scene id(698064d69a2d25162065001f):message] data update.
# [scene id(698064e558aedbb817a4e693):message] data update.
# [scene id(698064f48f8ba0ba2e6f7d19):message] data update.
# [scene id(69806517d3bfe9c3024f166f):message] data update.
# [scene id(6980652a4a8e83c1c91eb299):message] data update.
# [scene id(6980654cd88532d9c6962341):message] data update.
# [scene id(69806563c0b7633062003add):message] data update.
# [scene id(69806583f5c0a145cf96ce97):message] data update.
# [scene id(698065a64b50aa3aba12e06f):message] data update.
# [scene id(698065bfd5c549fb095d30ba):message] data update.
# [scene id(69806612ea66162937ae1d3f):message] data update.
# [scene id(698066313222b4369396b5ea):message] data update.
# [scene id(698066593852be754c1f20fc):message] data update.
# [scene id(6980667edde3b66db31fc00b):message] data update.
# [scene id(698066a1646b20141bb889a4):message] data update.
# [scene id(698066cf2e7529cc2846266b):message] data update.
# [scene id(698066e9431de354e1a7bf97):message] data update.
# [scene id(6980671bda1b0587ccec7f92):message] data update.
# [scene id(698067463593abbe13f792b5):message] data update.
# [scene id(69806760e66b92fd73ab275a):message] data update.
# [scene id(69806780edd3666fe15ac209):message] data update.
# [scene id(6980679c431919f825a445c1):message] data update.
# [scene id(698067c677d17de81d098a3d):message] data update.
# [scene id(698067fb02970943924d3ae2):message] data update.
# [scene id(6980681ae081ece0901ed2fe):message] data update.
# [scene id(69806834faf483f4d9fd768b):message] data update.
# [scene id(698068451401401f66f6cddb):message] data update.
# [scene id(6980685aa1f593e1252e93f2):message] data update.
# [scene id(69806886614939d8261044b0):message] data update.
# [scene id(698068a4c08af5576fd41ea2):message] data update.
# [scene id(698068bb0e59b33ef70540ac):message] data update.
# [scene id(698068e9696bd1f61b94eed3):message] data update.
# [scene id(6980690dd6b2d09dc2a92278):message] data update.
# [scene id(6980696378b7e4ac1bc0ca6a):message] data update.
# [scene id(69806983480810be9f0c8183):message] data update.
# [scene id(698069aa3fdfa5cdf461553e):message] data update.
# [scene id(698069bc7aaa344ac487282c):message] data update.
# [scene id(698069cdefe1741b4d6e486a):message] data update.
# [scene id(698069fa1a6519753a55cb7f):message] data update.
# [scene id(69806a14bb4cd8c41193b994):message] data update.
# [scene id(69806a57bf7a02e328cc99ec):message] data update.
# [scene id(69806a6d7f61dd65b41cb94f):message] data update.
# [scene id(69806a820d4425691d5cc39f):message] data update.
# [scene id(69806a98d3a0b11001358f44):message] data update.
# [scene id(69806ac2529f5c0d97794cd2):message] data update.
# [scene id(69806aeb601e953a6922137c):message] data update.
# [scene id(69806b0f22e6dc317eb43b28):message] data update.
# [scene id(69806b26c26f5fc9665d93e8):message] data update.
# [scene id(69806b3ab24a4dae2b3c374b):message] data update.
# [scene id(69806b87c02f54d6a1d571a1):message] data update.
# [scene id(69806b9f06e9fc0a07147ce2):message] data update.
# [scene id(69806bb7b6a23a2c3d47090c):message] data update.
# [scene id(69806be64c5195afe35911f0):message] data update.
# [scene id(69806c0d85adec641a5f0276):message] data update.
# [scene id(69806c2d5fcdf3712bacb3c1):message] data update.
# [scene id(69806c514ea87905164d616a):message] data update.
# [scene id(69806c80c2deb4fcc87049b1):message] data update.
# [scene id(69806c9eb6ee0f12ae9348eb):message] data update.
# [scene id(69806cb33fc253e651de171d):message] data update.
# [scene id(69806cc519d166079796935c):message] data update.
# [scene id(69806cd226624e8b6fd40cbd):message] data update.
# [scene id(69806ceb65d632c358916209):message] data update.
# [scene id(69806d0ae412f926c376a1da):message] data update.
# [scene id(69806d242a2b52f75e68ec9f):message] data update.
# [scene id(69806d384d63368cca2db160):message] data update.
# [scene id(69806d55b2a352c8721d36b2):message] data update.
# [scene id(69806d73b260454e34683829):message] data update.
# [scene id(69806d89c88244d624a818ba):message] data update.
# [scene id(69806dea826e1d54827a5ed6):message] data update.
# [scene id(69806dfca251603876638495):message] data update.
# [scene id(69806e11fbdaa5277ebde163):message] data update.
# [scene id(69806e218a0668576c7488a1):message] data update.
# [scene id(69806e363df88b5cdf01e309):message] data update.
# [scene id(69806e4656b9448c3e92635a):message] data update.
# [scene id(69806e83b3b19ce1cb337293):message] data update.
# [scene id(69806e9e77e6704125093612):message] data update.
# [scene id(69806ebfde56e8f2cbf54f1b):message] data update.
# [scene id(69806ed8d1578de65c8b4126):message] data update.
# [scene id(69806f0c04f5eae86c12b786):message] data update.
# [scene id(69806f20ab3177af7e0d6943):message] data update.
# [scene id(69806f2ea7e423b252045a3e):message] data update.
# [scene id(69806f48bd12bec07f8927ab):message] data update.
# [scene id(69806f653fe526f168117c5d):message] data update.
# [scene id(69806f88314cdc3ce1170e7e):message] data update.
# [scene id(69806faa33af3781c8b20d90):message] data update.
# [scene id(69806fc1ed46be2c4cc133ed):message] data update.
# [scene id(69806fe6bed663b4a6e6eb1c):message] data update.
# [scene id(698070201ff8b62e0288b392):message] data update.
# [scene id(6980703f511924972fdd9431):message] data update.
# [scene id(69807056ff795b8d31e10b38):message] data update.
# [scene id(69807069364cab8fc13dcd82):message] data update.
# [scene id(6980707bbd66fcf571509d62):message] data update.
# [scene id(6980709e3863d5594822a625):message] data update.
# [scene id(698070bba8d430166da57528):message] data update.
# [scene id(698070ce7b7ddead773407de):message] data update.
# [scene id(698070e94285bfb84dfc8b2e):message] data update.
# [scene id(698070fb07060002ef5596b2):message] data update.
# [scene id(6980710feed68b7f9eda4f49):message] data update.
# [scene id(6980712372929ed232e5f35a):message] data update.
# [scene id(69807138a1914da15c7ccd68):message] data update.
# [scene id(69807153dd1a81cfc295dfc1):message] data update.
# [scene id(6980716a7bac257d308c7170):message] data update.
# [scene id(698071853f313efcf57d29e5):message] data update.
# [scene id(698071d4b98eb64679d2d061):message] data update.
# [scene id(698071e5c1fb3e372f4fad67):message] data update.
# [scene id(698071f2ddb83d30f524fddf):message] data update.
# [scene id(69807216eb720d16a440bfda):message] data update.
# [scene id(6980722cd0db7d0ef17d0142):message] data update.
# [scene id(6980723ae36ac7dc6ee36503):message] data update.
# [scene id(698072484ccc86dce7fd41f3):message] data update.
# [scene id(698072604ed3c755888be4db):message] data update.
# [scene id(69807272535d99bbaa8cf637):message] data update.
# [scene id(6980728826eb2ec8dfacc725):message] data update.
# [scene id(698072ea0b4be81475878afe):message] data update.
# [scene id(69807304cf94e53067a433e8):message] data update.
# [scene id(6980754bb452d007643cb9de):message] data update.
# [scene id(6980756e390a0fab71c92702):message] data update.
# [scene id(6980757f5a02bf35a76a8090):message] data update.
# [scene id(69807590d641be3fe980b9df):message] data update.
# [scene id(698075a8f74163c6a158c02a):message] data update.
# [scene id(698075c0fbe76543abbec62f):message] data update.
# [scene id(698075d3dc114e3d565a20c7):message] data update.
# [scene id(698075e738d38b6e8515edc3):message] data update.
# [scene id(69807621b6884923db190bd9):message] data update.
# [scene id(6980763bd7d910a2d395e6b6):message] data update.
# [scene id(6980764e23c8ee7db200c6c5):message] data update.
# [scene id(6980765f4352284d0fbcb92d):message] data update.
# [scene id(6980767580fa6481e11a6bb3):message] data update.
# [scene id(698076b5dafd8f169931e9e2):message] data update.
# [scene id(698076c744777f50560e8c77):message] data update.
# [scene id(698078fd64f57875a31c58a3):message] data update.
# [scene id(698079ee31b399468e097a47):message] data update.
# [scene id(69807a0fdc86124cb456dd74):message] data update.
# [scene id(69807a33a38dace945277a5b):message] data update.
# [scene id(69823b907c09cd9088bcf886):message] data update.
# [scene id(698265572bb4c7a479e224b6):message] data update.
# [scene id(6982656c314b438b71cc3652):message] data update.
# [scene id(69826580454853ac4fd24803):message] data update.
