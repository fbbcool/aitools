# %%
from aidb.scene_manager import SceneManager
from aidb.scene import Scene

scm = SceneManager()
iscm = scm.scene_image_manager()
# Out:
# MongoDB connection configuration loaded from '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_test_scenes.yaml'.
# Thumbnail configuration loaded from '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_test_scenes.yaml'.
# Train image configuration loaded from '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_test_scenes.yaml'.
# Warning: 'hf_dataset_settings' section not found or malformed in '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_test_scenes.yaml'. Using default HF dataset settings.
# Successfully connected to MongoDB at mongodb://mongo:mongo@192.168.0.120:27017, database: test_scenes_new
# Using collection

# %%
scm.scenes_update()
# Out:
# [scene id(696e2ed878deb8af7a6d797c):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d797d):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d797e):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d797f):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7980):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7981):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7982):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7983):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7984):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7985):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7986):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7987):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7988):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7989):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d798a):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d798b):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d798c):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d798d):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d798e):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d798f):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7990):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7991):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7992):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7993):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7994):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7995):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7996):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7997):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7998):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d7999):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d799a):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d799b):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d799c):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d799d):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d799e):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d799f):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79a0):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79a1):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79a2):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79a3):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79a4):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79a5):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79a6):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79a7):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79a8):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79a9):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79aa):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79ab):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79ac):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79ad):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79ae):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79af):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79b0):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79b1):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79b2):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79b3):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79b4):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79b5):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79b6):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79b7):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79b8):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79b9):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79ba):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79bb):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79bc):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79bd):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79be):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79bf):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79c0):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79c1):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79c2):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79c3):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79c4):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79c5):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79c6):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79c7):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79c8):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79c9):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79ca):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79cb):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79cc):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79cd):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79ce):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79cf):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79d0):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79d1):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79d2):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79d3):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79d4):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79d5):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79d6):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79d7):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79d8):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79d9):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79da):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79db):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79dc):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79dd):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79de):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79df):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79e0):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79e1):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79e2):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79e3):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79e4):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79e5):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79e6):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79e7):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79e8):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79e9):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79ea):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79eb):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79ec):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79ed):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79ee):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79ef):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79f0):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79f1):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79f2):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79f3):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79f4):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79f5):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79f6):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79f7):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79f8):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79f9):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79fa):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79fb):message] thumbnail update.
# [scene id(696e2ed878deb8af7a6d79fc):message] thumbnail update.
# [scm:warning] Scene (id=69733dc6c8a9cbea9428bed7, url=/home/misw/Data/AI/scenes/0129) doesn't physically exist!
# [scene id(69733ef902b8ab10709a34fd):message] thumbnail update.
# [scene id(69790576fa90259160ef55d5):message] thumbnail update.
# [scene id(69790576fa90259160ef55d6):message] thumbnail update.
# [scene id(69790576fa90259160ef55d7):message] thumbnail update.
# [scene id(69790576fa90259160ef55d8):message] thumbnail update.
# [scene id(69790576fa90259160ef55d9):message] thumbnail update.
# [scene id(69790576fa90259160ef55da):message] thumbnail update.
# [scene id(69790576fa90259160ef55db):message] thumbnail update.
# [scene id(69790576fa90259160ef55dc):message] thumbnail update.
# [scene id(69790576fa90259160ef55dd):message] thumbnail update.
# [scene id(69790576fa90259160ef55de):message] thumbnail update.
# [scene id(69790576fa90259160ef55df):message] thumbnail update.
# [scene id(69790576fa90259160ef55e0):message] thumbnail update.
# [scene id(69790576fa90259160ef55e1):message] thumbnail update.
# [scene id(69790577fa90259160ef55e2):message] thumbnail update.
# [scene id(69790577fa90259160ef55e3):message] thumbnail update.
# [scene id(69790577fa90259160ef55e4):message] thumbnail update.
# [scene id(69790577fa90259160ef55e5):message] thumbnail update.
# [scene id(69790577fa90259160ef55e6):message] thumbnail update.
# [scene id(69790577fa90259160ef55e7):message] thumbnail update.
# [scene id(69790577fa90259160ef55e8):message] thumbnail update.
# [scene id(69790577fa90259160ef55e9):message] thumbnail update.
# [scene id(69790577fa90259160ef55ea):message] thumbnail update.
# [scene id(69790577fa90259160ef55eb):message] thumbnail update.
# [scene id(69790577fa90259160ef55ec):message] thumbnail update.
# [scene id(69790577fa90259160ef55ed):message] thumbnail update.
# [scene id(69790577fa90259160ef55ee):message] thumbnail update.
# [scene id(69790577fa90259160ef55ef):message] thumbnail update.
# [scene id(69790577fa90259160ef55f0):message] thumbnail update.
# [scene id(69790577fa90259160ef55f1):message] thumbnail update.
# [scene id(69790577fa90259160ef55f2):message] thumbnail update.
# [scene id(69790577fa90259160ef55f3):message] thumbnail update.
# [scene id(69790577fa90259160ef55f4):message] thumbnail update.
# [scene id(69790577fa90259160ef55f5):message] thumbnail update.
# [scene id(69790577fa90259160ef55f6):message] thumbnail update.
# [scene id(69790577fa90259160ef55f7):message] thumbnail update.
# [scene id(69790577fa90259160ef55f8):message] thumbnail update.
# [scene id(69790577fa90259160ef55f9):message] thumbnail update.
# [scene id(69790577fa90259160ef55fa):message] thumbnail update.
# [scene id(69790577fa90259160ef55fb):message] thumbnail update.
# [scene id(69790577fa90259160ef55fc):message] thumbnail update.
# [scene id(69790577fa90259160ef55fd):message] thumbnail update.
# [scene id(69790577fa90259160ef55fe):message] thumbnail update.
# [scene id(69790577fa90259160ef55ff):message] thumbnail update.
# [scene id(69790577fa90259160ef5600):message] thumbnail update.
# [scene id(69790577fa90259160ef5601):message] thumbnail update.
# [scene id(69790577fa90259160ef5602):message] thumbnail update.
# [scene id(69790577fa90259160ef5603):message] thumbnail update.
# [scene id(69790577fa90259160ef5604):message] thumbnail update.
# [scene id(69790577fa90259160ef5605):message] thumbnail update.
# [scene id(69790577fa90259160ef5606):message] thumbnail update.
# [scene id(69790577fa90259160ef5607):message] thumbnail update.
# [scene id(69790577fa90259160ef5608):message] thumbnail update.
# [scene id(69790577fa90259160ef5609):message] thumbnail update.
# [scene id(69790577fa90259160ef560a):message] thumbnail update.
# [scene id(69790577fa90259160ef560b):message] thumbnail update.
# [scene id(69790577fa90259160ef560c):message] thumbnail update.
# [scene id(69790577fa90259160ef560d):message] thumbnail update.
# [scene id(69790577fa90259160ef560e):message] thumbnail update.
# [scene id(69790577fa90259160ef560f):message] thumbnail update.
# [scene id(69790577fa90259160ef5610):message] thumbnail update.
# [scene id(69790577fa90259160ef5611):message] thumbnail update.
# [scene id(69790577fa90259160ef5612):message] thumbnail update.
# [scene id(69790577fa90259160ef5613):message] thumbnail update.
# [scene id(69790577fa90259160ef5614):message] thumbnail update.
# [scene id(69790577fa90259160ef5615):message] thumbnail update.
# [scene id(69790577fa90259160ef5616):message] thumbnail update.
# [scene id(69790577fa90259160ef5617):message] thumbnail update.
# [scene id(69790577fa90259160ef5618):message] thumbnail update.
# [scene id(69790577fa90259160ef5619):message] thumbnail update.
# [scene id(69790577fa90259160ef561a):message] thumbnail update.
# [scene id(69790577fa90259160ef561b):message] thumbnail update.
# [scene id(69790577fa90259160ef561c):message] thumbnail update.
# [scene id(69790577fa90259160ef561d):message] thumbnail update.
# [scene id(69790577fa90259160ef561e):message] thumbnail update.
# [scene id(69790577fa90259160ef561f):message] thumbnail update.
# [scene id(69790577fa90259160ef5620):message] thumbnail update.
# [scene id(69790577fa90259160ef5621):message] thumbnail update.
# [scene id(69790577fa90259160ef5622):message] thumbnail update.
# [scene id(69790577fa90259160ef5623):message] thumbnail update.
# [scene id(69790577fa90259160ef5624):message] thumbnail update.
# [scene id(69790577fa90259160ef5625):message] thumbnail update.
# [scene id(69790577fa90259160ef5626):message] thumbnail update.
# [scene id(69790577fa90259160ef5627):message] thumbnail update.
# [scene id(69790577fa90259160ef5628):message] thumbnail update.
# [scene id(69790577fa90259160ef5629):message] thumbnail update.
# [scene id(69790577fa90259160ef562a):message] thumbnail update.
# [scene id(69790577fa90259160ef562b):message] thumbnail update.
# [scene id(69790577fa90259160ef562c):message] thumbnail update.
# [scene id(69790577fa90259160ef562d):message] thumbnail update.
# [scene id(69790577fa90259160ef562e):message] thumbnail update.
# [scene id(69790577fa90259160ef562f):message] thumbnail update.
# [scene id(69790577fa90259160ef5630):message] thumbnail update.
# [scene id(69790577fa90259160ef5631):message] thumbnail update.
# [scene id(69790577fa90259160ef5632):message] thumbnail update.
# [scene id(69790577fa90259160ef5633):message] thumbnail update.
# [scene id(69790577fa90259160ef5634):message] thumbnail update.
# [scene id(69790577fa90259160ef5635):message] thumbnail update.
# [scene id(69790577fa90259160ef5636):message] thumbnail update.
# [scene id(69790577fa90259160ef5637):message] thumbnail update.
# [scene id(69790577fa90259160ef5638):message] thumbnail update.
# [scene id(69790577fa90259160ef5639):message] thumbnail update.
# [scene id(69790577fa90259160ef563a):message] thumbnail update.
# [scene id(69790577fa90259160ef563b):message] thumbnail update.
# [scene id(69790577fa90259160ef563c):message] thumbnail update.
# [scene id(69790577fa90259160ef563d):message] thumbnail update.
# [scene id(69790577fa90259160ef563e):message] thumbnail update.
# [scene id(69790577fa90259160ef563f):message] thumbnail update.
# [scene id(69790577fa90259160ef5640):message] thumbnail update.
# [scene id(69790577fa90259160ef5641):message] thumbnail update.
# [scene id(69790577fa90259160ef5642):message] thumbnail update.
# [scene id(69790577fa90259160ef5643):message] thumbnail update.
# [scene id(6979127e6743ba0738629c71):message] thumbnail update.
# [scene id(6979127e6743ba0738629c72):message] thumbnail update.
# [scene id(6979127e6743ba0738629c73):message] thumbnail update.
# [scene id(6979127e6743ba0738629c74):message] thumbnail update.
# [scene id(6979127e6743ba0738629c75):message] thumbnail update.
# [scene id(6979127e6743ba0738629c76):message] thumbnail update.
# [scene id(6979127e6743ba0738629c77):message] thumbnail update.
# [scene id(6979127e6743ba0738629c78):message] thumbnail update.
# [scene id(6979127e6743ba0738629c79):message] thumbnail update.
# [scene id(6979127e6743ba0738629c7a):message] thumbnail update.
# [scene id(6979127e6743ba0738629c7b):message] thumbnail update.
# [scene id(697912bf7bb4879d3388085a):message] thumbnail update.
# [scene id(697912bf7bb4879d3388085b):message] thumbnail update.
# [scene id(697912bf7bb4879d3388085c):message] thumbnail update.
# [scene id(697912bf7bb4879d3388085d):message] thumbnail update.
# [scene id(697912bf7bb4879d3388085e):message] thumbnail update.
# [scene id(697912bf7bb4879d3388085f):message] thumbnail update.
# [scene id(697912bf7bb4879d33880860):message] thumbnail update.
# [scene id(697912bf7bb4879d33880861):message] thumbnail update.
# [scene id(697912bf7bb4879d33880862):message] thumbnail update.
# [scene id(697912bf7bb4879d33880863):message] thumbnail update.
# [scene id(697912bf7bb4879d33880864):message] thumbnail update.
# [scene id(69791aaf80c61c72eff16b89):message] thumbnail update.
# [scene id(69791aaf80c61c72eff16b8a):message] thumbnail update.
# [scene id(69791aaf80c61c72eff16b8b):message] thumbnail update.
# [scene id(69791aaf80c61c72eff16b8c):message] thumbnail update.
# [scene id(69791aaf80c61c72eff16b8d):message] thumbnail update.
# [scene id(69791aaf80c61c72eff16b8e):message] thumbnail update.
# [scene id(69791aaf80c61c72eff16b8f):message] thumbnail update.
# [scene id(69791aaf80c61c72eff16b90):message] thumbnail update.
# [scene id(69791aaf80c61c72eff16b91):message] thumbnail update.
# [scene id(69791aaf80c61c72eff16b92):message] thumbnail update.
# [scene id(69791aaf80c61c72eff16b93):message] thumbnail update.
# [scene id(69791aaf80c61c72eff16b94):message] thumbnail update.
# [scene id(69791aaf80c61c72eff16b95):message] thumbnail update.
# [scene id(69791aaf80c61c72eff16b96):message] thumbnail update.
# [scene id(69791aaf80c61c72eff16b97):message] thumbnail update.
# [scene id(69791aaf80c61c72eff16b98):message] thumbnail update.
# [scene id(69791af6afcf8d9f3abe4fb6):message] thumbnail update.
# [scene id(69791af6afcf8d9f3abe4fb7):message] thumbnail update.
# [scene id(69791af6afcf8d9f3abe4fb8):message] thumbnail update.

# %%
url = '/home/misw/Data/AI/scenes/0128'
id = '696e2ed878deb8af7a6d79fc'
#id = scm.id_from_url(url)
scene1 = Scene(scm,id)
scene2 = Scene(scm,url)
scene = scene1
print(scene1)
print(scene2)

# %%
scene3 = scm.scene_from_id_or_url(id)

# %%
print(scene3)

# %%
scene4 = scm.scene_from_id_or_url(url)

# %%
print(scene4)

# %%
url_img = '/home/misw/Downloads/999_test/ComfyUI_temp_ilmep_00006_.png'
id = iscm.register_from_url(url_img)
id

# %%
url_reg = '/home/misw/Downloads/999_test/orig___697758387ef596695ff19a74.png'
id = iscm.register_from_url(url_img)
id

# %%
scene3._update_thumbnail()
