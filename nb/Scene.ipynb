# %%
from aidb import SceneManager, Scene, SceneDef

scm = SceneManager(config=SceneDef.CONFIG_PROD)
iscm = scm.scene_image_manager()
# Out:
# [dbm:message] MongoDB connection configuration loaded from '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_scenes_prod.yaml'.
# [dbm:message] Thumbnail configuration loaded from '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_scenes_prod.yaml'.
# [dbm:message] Train image configuration loaded from '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_scenes_prod.yaml'.
# [dbm:message] Warning: 'hf_dataset_settings' section not found or malformed in '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_scenes_prod.yaml'. Using default HF dataset settings.
# [dbm:message] Successfully connected to MongoDB at mongodb://mongo:mongo@192.168.0.120:27017, database: scenes_prod
# [dbm:message] Using collection

# %%
scm.scenes_update()
# Out:
# [scene id(6979ed1109bc968f483a60f1):message] thumbnail update.
# [scene id(6979ed790a75d3d578dfe485):message] thumbnail update.
# [scene id(6979ed790a75d3d578dfe486):message] thumbnail update.
# [scene id(6979ed790a75d3d578dfe487):message] thumbnail update.
# [scene id(6979ed790a75d3d578dfe488):message] thumbnail update.
# [scene id(6979ed790a75d3d578dfe489):message] thumbnail update.
# [scene id(6979ed790a75d3d578dfe48a):message] thumbnail update.
# [scene id(6979ed790a75d3d578dfe48b):message] thumbnail update.
# [scene id(6979ed790a75d3d578dfe48c):message] thumbnail update.
# [scene id(6979ed790a75d3d578dfe48d):message] thumbnail update.
# [scene id(6979ed790a75d3d578dfe48e):message] thumbnail update.
# [scene id(6979ed790a75d3d578dfe48f):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe490):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe491):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe492):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe493):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe494):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe495):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe496):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe497):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe498):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe499):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe49a):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe49b):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe49c):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe49d):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe49e):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe49f):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4a0):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4a1):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4a2):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4a3):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4a4):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4a5):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4a6):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4a7):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4a8):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4a9):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4aa):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4ab):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4ac):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4ad):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4ae):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4af):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4b0):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4b1):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4b2):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4b3):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4b4):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4b5):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4b6):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4b7):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4b8):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4b9):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4ba):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4bb):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4bc):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4bd):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4be):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4bf):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4c0):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4c1):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4c2):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4c3):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4c4):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4c5):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4c6):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4c7):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4c8):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4c9):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4ca):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4cb):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4cc):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4cd):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4ce):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4cf):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4d0):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4d1):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4d2):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4d3):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4d4):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4d5):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4d6):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4d7):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4d8):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4d9):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4da):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4db):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4dc):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4dd):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4de):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4df):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4e0):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4e1):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4e2):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4e3):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4e4):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4e5):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4e6):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4e7):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4e8):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4e9):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4ea):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4eb):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4ec):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4ed):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4ee):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4ef):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4f0):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4f1):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4f2):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4f3):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4f5):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4f6):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4f7):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4f8):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4f9):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4fa):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4fb):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4fc):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4fd):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4fe):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe4ff):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe500):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe501):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe502):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe503):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe504):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe505):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe506):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe507):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe508):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe509):message] thumbnail update.
# [scene id(6979ed7a0a75d3d578dfe50a):message] thumbnail update.
# [scene id(6979edd3a65b872466c06294):message] thumbnail update.
# [scene id(6979edd3a65b872466c06295):message] thumbnail update.
# [scene id(6979edd3a65b872466c06296):message] thumbnail update.
# [scene id(6979edd3a65b872466c06297):message] thumbnail update.
# [scene id(6979edd3a65b872466c06298):message] thumbnail update.
# [scene id(6979edd4a65b872466c06299):message] thumbnail update.
# [scene id(6979edd4a65b872466c0629a):message] thumbnail update.
# [scene id(6979edd4a65b872466c0629b):message] thumbnail update.
# [scene id(6979edd4a65b872466c0629c):message] thumbnail update.
# [scene id(6979edd4a65b872466c0629d):message] thumbnail update.
# [scene id(6979edd4a65b872466c0629e):message] thumbnail update.
# [scene id(6979edd4a65b872466c0629f):message] thumbnail update.
# [scene id(6979edd4a65b872466c062a0):message] thumbnail update.
# [scene id(6979edd4a65b872466c062a1):message] thumbnail update.
# [scene id(6979edd4a65b872466c062a2):message] thumbnail update.
# [scene id(6979edd4a65b872466c062a3):message] thumbnail update.
# [scene id(6979edd4a65b872466c062a4):message] thumbnail update.
# [scene id(6979edd4a65b872466c062a5):message] thumbnail update.
# [scene id(6979edd4a65b872466c062a6):message] thumbnail update.
# [scene id(6979edd4a65b872466c062a7):message] thumbnail update.
# [scene id(6979edd4a65b872466c062a8):message] thumbnail update.
# [scene id(6979edd4a65b872466c062a9):message] thumbnail update.
# [scene id(6979edd4a65b872466c062aa):message] thumbnail update.
# [scene id(6979edd4a65b872466c062ab):message] thumbnail update.
# [scene id(6979edd4a65b872466c062ac):message] thumbnail update.
# [scene id(6979edd4a65b872466c062ad):message] thumbnail update.
# [scene id(6979edd4a65b872466c062ae):message] thumbnail update.
# [scene id(6979edd4a65b872466c062af):message] thumbnail update.
# [scene id(6979edd4a65b872466c062b0):message] thumbnail update.
# [scene id(6979edd4a65b872466c062b1):message] thumbnail update.
# [scene id(6979edd4a65b872466c062b2):message] thumbnail update.
# [scene id(6979edd4a65b872466c062b3):message] thumbnail update.
# [scene id(6979edd4a65b872466c062b4):message] thumbnail update.
# [scene id(6979edd4a65b872466c062b5):message] thumbnail update.
# [scene id(6979edd4a65b872466c062b6):message] thumbnail update.
# [scene id(6979edd4a65b872466c062b7):message] thumbnail update.
# [scene id(6979edd4a65b872466c062b8):message] thumbnail update.
# [scene id(6979edd4a65b872466c062b9):message] thumbnail update.
# [scene id(6979edd4a65b872466c062ba):message] thumbnail update.
# [scene id(6979edd4a65b872466c062bb):message] thumbnail update.
# [scene id(6979edd4a65b872466c062bc):message] thumbnail update.
# [scene id(6979edd4a65b872466c062bd):message] thumbnail update.
# [scene id(6979edd4a65b872466c062be):message] thumbnail update.
# [scene id(6979edd4a65b872466c062bf):message] thumbnail update.
# [scene id(6979edd4a65b872466c062c0):message] thumbnail update.
# [scene id(6979edd4a65b872466c062c1):message] thumbnail update.
# [scene id(6979edd4a65b872466c062c2):message] thumbnail update.
# [scene id(6979edd4a65b872466c062c3):message] thumbnail update.
# [scene id(6979edd4a65b872466c062c4):message] thumbnail update.
# [scene id(6979edd4a65b872466c062c5):message] thumbnail update.
# [scene id(6979edd4a65b872466c062c6):message] thumbnail update.
# [scene id(6979edd4a65b872466c062c7):message] thumbnail update.
# [scene id(6979edd4a65b872466c062c8):message] thumbnail update.
# [scene id(6979edd4a65b872466c062c9):message] thumbnail update.
# [scene id(6979edd4a65b872466c062ca):message] thumbnail update.
# [scene id(6979edd4a65b872466c062cb):message] thumbnail update.
# [scene id(6979edd4a65b872466c062cc):message] thumbnail update.
# [scene id(6979edd4a65b872466c062cd):message] thumbnail update.
# [scene id(6979edd4a65b872466c062ce):message] thumbnail update.
# [scene id(6979edd4a65b872466c062cf):message] thumbnail update.
# [scene id(6979edd4a65b872466c062d0):message] thumbnail update.
# [scene id(6979edd4a65b872466c062d1):message] thumbnail update.
# [scene id(6979edd4a65b872466c062d2):message] thumbnail update.
# [scene id(6979edd4a65b872466c062d3):message] thumbnail update.
# [scene id(6979edd4a65b872466c062d4):message] thumbnail update.
# [scene id(6979edd4a65b872466c062d5):message] thumbnail update.
# [scene id(6979edd4a65b872466c062d6):message] thumbnail update.
# [scene id(6979edd4a65b872466c062d7):message] thumbnail update.
# [scene id(6979edd4a65b872466c062d8):message] thumbnail update.
# [scene id(6979edd4a65b872466c062d9):message] thumbnail update.
# [scene id(6979edd4a65b872466c062da):message] thumbnail update.
# [scene id(6979edd4a65b872466c062db):message] thumbnail update.
# [scene id(6979edd4a65b872466c062dc):message] thumbnail update.
# [scene id(6979edd4a65b872466c062dd):message] thumbnail update.
# [scene id(6979edd4a65b872466c062de):message] thumbnail update.
# [scene id(6979edd4a65b872466c062df):message] thumbnail update.
# [scene id(6979edd4a65b872466c062e0):message] thumbnail update.
# [scene id(6979edd4a65b872466c062e1):message] thumbnail update.
# [scene id(6979edd4a65b872466c062e2):message] thumbnail update.
# [scene id(6979edd4a65b872466c062e3):message] thumbnail update.
# [scene id(6979edd4a65b872466c062e4):message] thumbnail update.
# [scene id(6979edd4a65b872466c062e5):message] thumbnail update.
# [scene id(6979edd4a65b872466c062e6):message] thumbnail update.
# [scene id(6979edd4a65b872466c062e7):message] thumbnail update.
# [scene id(6979edd4a65b872466c062e8):message] thumbnail update.
# [scene id(6979edd4a65b872466c062e9):message] thumbnail update.
# [scene id(6979edd4a65b872466c062ea):message] thumbnail update.
# [scene id(6979edd4a65b872466c062eb):message] thumbnail update.
# [scene id(6979edd4a65b872466c062ec):message] thumbnail update.
# [scene id(6979edd4a65b872466c062ed):message] thumbnail update.
# [scene id(6979edd4a65b872466c062ee):message] thumbnail update.
# [scene id(6979edd4a65b872466c062ef):message] thumbnail update.
# [scene id(6979edd4a65b872466c062f0):message] thumbnail update.
# [scene id(6979edd4a65b872466c062f1):message] thumbnail update.
# [scene id(6979edd4a65b872466c062f2):message] thumbnail update.
# [scene id(6979edd4a65b872466c062f3):message] thumbnail update.
# [scene id(6979edd4a65b872466c062f4):message] thumbnail update.
# [scene id(6979edd4a65b872466c062f5):message] thumbnail update.
# [scene id(6979edd4a65b872466c062f6):message] thumbnail update.
# [scene id(6979edd4a65b872466c062f7):message] thumbnail update.
# [scene id(6979edd4a65b872466c062f8):message] thumbnail update.
# [scene id(6979edd4a65b872466c062f9):message] thumbnail update.
# [scene id(6979edd4a65b872466c062fa):message] thumbnail update.
# [scene id(6979edd4a65b872466c062fb):message] thumbnail update.
# [scene id(6979edd4a65b872466c062fc):message] thumbnail update.
# [scene id(6979edd4a65b872466c062fd):message] thumbnail update.
# [scene id(6979edd4a65b872466c062fe):message] thumbnail update.
# [scene id(6979edd4a65b872466c062ff):message] thumbnail update.
# [scene id(6979edd4a65b872466c06300):message] thumbnail update.
# [scene id(6979edd4a65b872466c06301):message] thumbnail update.
# [scene id(6979edd4a65b872466c06302):message] thumbnail update.
# [scene id(6979edd4a65b872466c06303):message] thumbnail update.
# [scene id(6979edd4a65b872466c06304):message] thumbnail update.
# [scene id(6979edd4a65b872466c06305):message] thumbnail update.
# [scene id(6979edd4a65b872466c06306):message] thumbnail update.
# [scene id(6979edd4a65b872466c06307):message] thumbnail update.
# [scene id(6979edd4a65b872466c06308):message] thumbnail update.
# [scene id(6979edd4a65b872466c06309):message] thumbnail update.
# [scene id(6979edd4a65b872466c0630a):message] thumbnail update.
# [scene id(6979edd4a65b872466c0630b):message] thumbnail update.
# [scene id(6979edd4a65b872466c0630c):message] thumbnail update.
# [scene id(6979edd4a65b872466c0630d):message] thumbnail update.
# [scene id(6979edd4a65b872466c0630e):message] thumbnail update.
# [scene id(6979edd4a65b872466c0630f):message] thumbnail update.
# [scene id(6979edd4a65b872466c06310):message] thumbnail update.
# [scene id(6979edd4a65b872466c06311):message] thumbnail update.
# [scene id(6979edd4a65b872466c06312):message] thumbnail update.
# [scene id(6979edd4a65b872466c06313):message] thumbnail update.
# [scene id(6979edd4a65b872466c06314):message] thumbnail update.
# [scene id(6979ee192e61e8082bdedc19):message] thumbnail update.
# [scene id(6979ee192e61e8082bdedc1a):message] thumbnail update.
# [scene id(6979ee192e61e8082bdedc1b):message] thumbnail update.
# [scene id(6979ee33b0fee1bc35e1903d):message] thumbnail update.
# [scene id(6979ee33b0fee1bc35e1903e):message] thumbnail update.
# [scene id(6979ee33b0fee1bc35e1903f):message] thumbnail update.
# [scene id(6979ee33b0fee1bc35e19040):message] thumbnail update.
# [scene id(6979ee33b0fee1bc35e19041):message] thumbnail update.
# [scene id(6979ee33b0fee1bc35e19042):message] thumbnail update.
# [scene id(6979ee33b0fee1bc35e19043):message] thumbnail update.
# [scene id(6979ee34b0fee1bc35e19044):message] thumbnail update.
# [scene id(6979ee34b0fee1bc35e19045):message] thumbnail update.
# [scene id(6979ee34b0fee1bc35e19046):message] thumbnail update.
# [scene id(6979ee34b0fee1bc35e19047):message] thumbnail update.
# [scene id(6979ee34b0fee1bc35e19048):message] thumbnail update.
# [scene id(6979ee34b0fee1bc35e19049):message] thumbnail update.
# [scene id(6979ee34b0fee1bc35e1904a):message] thumbnail update.
# [scene id(6979ee34b0fee1bc35e1904b):message] thumbnail update.
# [scene id(6979ee34b0fee1bc35e1904c):message] thumbnail update.

# %%
url = '/home/misw/Data/AI/scenes/0128'
id = '696e2ed878deb8af7a6d79fc'
#id = scm.id_from_url(url)
scene1 = Scene(scm,id)
scene2 = Scene(scm,url)
scene = scene1
print(scene1)
print(scene2)

# %%
scene3 = scm.scene_from_id_or_url(id)

# %%
print(scene3)

# %%
scene4 = scm.scene_from_id_or_url(url)

# %%
print(scene4)

# %%
url_img = '/home/misw/Downloads/999_test/ComfyUI_temp_ilmep_00006_.png'
id = iscm.register_from_url(url_img)
id

# %%
url_reg = '/home/misw/Downloads/999_test/orig___697758387ef596695ff19a74.png'
id = iscm.register_from_url(url_img)
id

# %%
scene3._update_thumbnail()
