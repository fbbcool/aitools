# %%
from aidb import SceneManager, Scene, SceneDef

scm = SceneManager(config=SceneDef.CONFIG_TEST)
iscm = scm.scene_image_manager()
# Out:
# [dbm:message] MongoDB connection configuration loaded from '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_scenes_test.yaml'.
# [dbm:message] Thumbnail configuration loaded from '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_scenes_test.yaml'.
# [dbm:message] Train image configuration loaded from '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_scenes_test.yaml'.
# [dbm:message] Warning: 'hf_dataset_settings' section not found or malformed in '/home/misw/venv/aitools/aitools/conf/aidb/dbmanager_scenes_test.yaml'. Using default HF dataset settings.
# [dbm:message] Successfully connected to MongoDB at mongodb://mongo:mongo@192.168.0.120:27017, database: scenes_test
# [dbm:message] Using collection

# %%
scm.scenes_update()

# %%
url = '/home/misw/Data/AI/scenes/0128'
id = '6979e5a1e7438cccb5e231d6' # TEST
#id = scm.id_from_url(url)
scene1 = Scene(scm,id)
#scene2 = Scene(scm,url)
scene3 = scm.scene_from_id_or_url(id)
scene = scene1
print(scene1)
#print(scene2)
print(scene3)

# %%
scene.set_rating(1)
scene.update()

# %%
for id in scm.ids_from_rating(-2,2):
    print(id)

# %%
url_img = '/home/misw/Downloads/999_test/ComfyUI_temp_ilmep_00006_.png'
id = iscm.register_from_url(url_img)
id

# %%
url_reg = '/home/misw/Downloads/999_test/orig___697758387ef596695ff19a74.png'
id = iscm.register_from_url(url_img)
id

# %%
scene3._update_thumbnail()

# %%
for id in scm.ids:
    scene = scm.scene_from_id_or_url(id)
    scene.set_labels([])
    scene.update()
# Out:
# [scene id(6979e5a1e7438cccb5e231d6):message] data update.
# [scene id(6979e5f3f4256b2570efc294):message] data update.
