# %%
from tools.ainstall import AInstallerDB, AInstaller
from pprint import pprint
base_dir = "/home/misw/venv/comfy2/ComfyUI"
group = "wan22:t2v"
AInstaller(base_dir, group=group, method="comfyui")
# Out:
# read models_comfyui.json
# read models_wan_lora.json
# read models_wan.json
# items for selected group wan22:
# *** trying ***
# {'config': {'method_download': 'huggingface', 'repo_id': 'fbbcool/wan22_lora'},
#  'group': 'wan22',
#  'target': 'lora',
#  'target_dir': '/home/misw/venv/comfy2/ComfyUI/models/loras/wan22',
#  'type': 'comfyui',
#  'variant': 'common'}
# try download hf:
# Fetching 47 files:   0%|          | 0/47 [00:00<?, ?it/s]
# *** trying ***
# {'config': {'file': 'split_files/vae/wan_2.1_vae.safetensors',
#             'method_download': 'huggingface',
#             'repo_id': 'Comfy-Org/Wan_2.2_ComfyUI_Repackaged'},
#  'group': 'wan22',
#  'target': 'vae',
#  'target_dir': '/home/misw/venv/comfy2/ComfyUI/models/vae/wan22',
#  'type': 'comfyui',
#  'variant': 'common'}
# try download hf:
# *** trying ***
# {'config': {'file': 'split_files/text_encoders/umt5_xxl_fp8_e4m3fn_scaled.safetensors',
#             'method_download': 'huggingface',
# ...
